# %% [markdown]
# # 01 — Data Exploration
# Profile schema, missing values, duplicates, target balance, distributions, and quality exceptions.

# %%
import pandas as pd
df = pd.read_csv('../data/sample_data/healthcare_sample.csv')
display(df.head())
print(df.shape)
display(df.dtypes.to_frame('dtype'))
display(df.isna().sum().to_frame('missing'))
print('duplicates:', df.duplicated().sum())
display(df['Test Results'].value_counts())
