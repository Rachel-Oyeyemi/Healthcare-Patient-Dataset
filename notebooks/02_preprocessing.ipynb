# %% [markdown]
# # 02 — Preprocessing
# Validate schema, remove exact duplicates, normalize text, parse dates, and add quality flags.

# %%
import sys, pandas as pd
sys.path.append('../src')
from preprocess import preprocess_dataframe
raw = pd.read_csv('../data/sample_data/healthcare_sample.csv')
clean = preprocess_dataframe(raw)
display(clean.head())
print(clean.shape)
